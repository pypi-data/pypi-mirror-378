# %% [markdown]
# ## Run a pipeline using dask and threads

# %% [markdown]
# This process will run the entire pipeline described in a configuration file using dask and threads

# %% [markdown]
# ## Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2
from paidiverpy.pipeline import Pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Instantiate the Pipeline class

# %% [markdown]
# This pipeline will process the dataset using dask and threads. In this case, as "n_jobs: -1", it will use all the processors that I have on my machine.

# %%
pipeline = Pipeline(config_file_path="../config_files/config_benthic_dask.yml", verbose=2)

# %%
pipeline.config
# Out:
# {
#     "general": {
#         "name": "raw",
#         "step_name": "open",
#         "sample_data": "benthic_csv",
#         "input_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/images",
#         "output_path": "output",
#         "metadata_path": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/metadata_benthic_csv.csv",
#         "metadata_type": "CSV_FILE",
#         "image_open_args": "PNG",
#         "append_data_to_metadata": "/home/tobfer/.paidiverpy_cache/benthic_csv/metadata/appended_metadata_benthic_csv.csv",
#         "n_jobs": -1,
#         "track_changes": true,
#         "sampling": [
#             {
#                 "name": "sampling",
#                 "step_name": "sampling",
#                 "test": false,
#                 "params": {
#                     "value": 20,
#                     "raise_error": false
#                 },
#                 "mode": "fixed"
#             }
#         ]
#     },
#     "steps": [
#         {
#             "name": "datetime",
#             "step_name": "sampling",
#             "test": false,
#             "params": {
#                 "min": "2018-06-11 04:14:00",
#                 "max": "2018-06-11 04:20:00",
#                 "raise_error": false
#             },
#             "mode": "datetime"
#         },
#         {
#             "name": "overlapping",
#             "step_name": "sampling",
#             "test": false,
#             "params": {
#                 "omega": 57.0,
#                 "theta": 40.0,
#                 "threshold": 0.5,
#                 "camera_distance": 1.12,
#                 "raise_error": false
#             },
#             "mode": "overlapping"
#         },
#         {
#             "name": "colour_alteration",
#             "step_name": "colour",
#             "test": false,
#             "params": {
#                 "method": "white_balance",
#                 "raise_error": false
#             },
#             "mode": "colour_alteration"
#         },
#         {
#             "name": "gaussian_blur",
#             "step_name": "colour",
#             "test": false,
#             "params": {
#                 "sigma": 1.0,
#                 "raise_error": false
#             },
#             "mode": "gaussian_blur"
#         },
#         {
#             "name": "sharpen",
#             "step_name": "colour",
#             "test": false,
#             "params": {
#                 "alpha": 1.5,
#                 "beta": -0.5,
#                 "raise_error": false
#             },
#             "mode": "sharpen"
#         },
#         {
#             "name": "contrast",
#             "step_name": "colour",
#             "test": false,
#             "params": {
#                 "method": "clahe",
#                 "clip_limit": 0.01,
#                 "gamma_value": 0.5,
#                 "raise_error": false
#             },
#             "mode": "contrast"
#         }
#     ]
# }

# %%
# See the pipeline steps. Click in a step to see more information about it
pipeline
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
# <defs>
# <symbol id="arrow-right" viewBox="0 0 330 330">
#   <path id="XMLID_222_" d="M250.606,154.389l-150-149.996c-5.857-5.858-15.355-5.858-21.213,0.001
# 	c-5.857,5.858-5.857,15.355,0.001,21.213l139.393,139.39L79.393,304.394c-5.857,5.858-5.857,15.355,0.001,21.213
# 	C82.322,328.536,86.161,330,90,330s7.678-1.464,10.607-4.394l149.999-150.004c2.814-2.813,4.394-6.628,4.394-10.606
# 	C255,161.018,253.42,157.202,250.606,154.389z"/>
# </defs>
# </svg>
# <style>/* CSS stylesheet for displaying Paidiverpy objects in jupyterlab.
#  *
#  */
#
# :root {
#   --ppy-font-color: var(--jp-content-font-color, rgba(0, 0, 0, 1));
#   --ppy-font-color-brown: var(--jp-content-font-color-brown, brown);
#   --ppy-font-color-olive: var(--jp-content-font-color-olive, olive);
#   --ppy-font-color-teal: var(--jp-content-font-color-teal, teal);
#   --ppy-font-color-blue: var(--jp-content-font-color-blue, blue);
#   --ppy-font-color-gray: var(--jp-content-font-color-gray, gray);
#   --ppy-border-color: var(--jp-border-color2, #e0e0e0);
#   --ppy-disabled-color: var(--jp-layout-color3, #bdbdbd);
#   --ppy-background-color: var(--jp-layout-color, white);
#   --ppy-background-color2: var(--jp-layout-color3, rgba(212, 212, 212, 0.15));
# }
#
#
# html[theme="dark"],
# html[data-theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --ppy-font-color: rgba(255, 255, 255, 1);
#   --ppy-font-color-brown: brown;
#   --ppy-font-color-olive: olive;
#   --ppy-font-color-teal: teal;
#   --ppy-font-color-blue: blue;
#   --ppy-font-color-gray: gray;
#   --ppy-border-color: #1f1f1f;
#   --ppy-disabled-color: #515151;
#   --ppy-background-color: #111111;
# }
#
# .ppy-background-color {
#   background-color: var(--ppy-background-color) !important;
# }
#
# .ppy-font-color-brown {
#   color: var(--ppy-font-color-brown) !important;
# }
#
# .ppy-font-color {
#   color: var(--ppy-font-color) !important;
# }
# .ppy-h2 {
#   font-size: 20px !important;
# }
# .ppy-h3 {
#   font-size: 13px !important;
# }
# .ppy-p {
#   font-size: 10px;
# }
# .ppy-p-error {
#   color: var(--ppy-font-color-brown);
#   font-weight: bold;
#   display: block;
# }
#
# .ppy-text-repr-fallback {
#   /* fallback to plain text repr when CSS is not injected (untrusted notebook) */
#   display: none;
# }
#
# .ppy-pipeline-wrap{
#   display: flex;
#   flex-wrap: wrap;
#   align-items: center;
# }
#
# .ppy-pipeline {
#   float:left;
#   cursor: pointer;
#   padding: 10px;
#   width: max-content;
#   height: 150px;
#   margin: 10px;
#   border: 1px solid #000;
#   text-align: center;
#   /* line-height: 80px; */
# }
#
# .ppy-pipeline-clear-fix {
#   clear: both;
# }
#
# .ppy-pipeline-parameters-all {
#   padding: 10px;
#   margin: 10px;
# }
#
# .ppy-images-step-header {
#   cursor: pointer;
#   font-weight: bold;
#   margin-top: 10px;
#   margin-bottom: 5px;
# }
# .ppy-images-metadata {
#   margin-left: 20px;
#   margin-bottom: 10px;
# }
# .ppy-images {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 10px;
#   margin-left: 20px;
# }
#
# .ppy-show-more-button, .ppy-hide-button {
#   margin-left: 20px;
#   background-color: #007bff;
#   color: white;
#   border: none;
#   padding: 5px 10px;
#   cursor: pointer;
# }
#
#
# .ppy-pipeline-arrow {
#   float:left;
#   width: 50px;
#   height: 80px;
#   margin: 10px;
#   text-align: center;
#   line-height: 80px;
# }
#
# .ppy-images-img{
#   display: block;
#   max-width: 200px;
#   margin: 10px;
# }
#
# .ppy-images-toggle-arrow {
#   cursor: pointer;
#   margin-left: 5px;
# }
#
# .ppy-images-image-p {
#   cursor: pointer;
# }
#
# .ppy-arrow-right {
#   display: inline-block;
#   vertical-align: middle;
#   width: 1em;
#   height: 1.5em !important;
#   stroke-width: 0;
#   stroke: currentColor;
#   fill: currentColor;
# }
#
#
# .ppy-json-block {
#   font-family: monospace;
#   background: var(--ppy-background-color);
#   padding: 1em;
#   border-radius: 6px;
# }
# .ppy-json-key {
#   color: var(--ppy-font-color-brown);
# }
# .ppy-json-string {
#   color: var(--ppy-font-color-olive);
# }
# .ppy-json-number {
#   color: var(--ppy-font-color-teal);
# }
# .ppy-json-bool {
#   color: var(--ppy-font-color-blue);
# }
# .ppy-json-null {
#   color: var(--ppy-font-color-gray);
# }
#
#
# .ppy-pn-title-0 {
#   font-size: 30px;
# }
#
# .ppy-pn-title-1 {
#   font-size: 20px;
# }
# .ppy-pn-title-2 {
#   font-size: 17px;
# }
# .ppy-pn-title-3 {
#   font-size: 14px;
# }
# .ppy-pn-title-4 {
#   font-size: 12px;
# }
#
# .ppy-pn-bold {
#   font-weight: bold;
# }
# .ppy-pn-italic {
#   font-style: italic;
# }
# .ppy-pn-description {
#   font-size: 14px;
#   margin-bottom: 1px;
# }
#
# .bk-root {
#   width: 100% !important;
#   max-width: 100% !important;
#   box-sizing: border-box;
# }
#
# input, .bk-input, .bk-input-group {
#   margin-top: 0px;
#   margin-bottom: 3px;
#   padding-top: 0px;
#   padding-bottom: 0px;
# }
#
# .ppy-pn-header-button .bk-btn {
#   background: none !important;
#   border: none !important;
#   font-weight: bold;
#   font-size: 16px;
#   text-align: left;
#   padding-left: 0;
#   cursor: pointer;
#   box-shadow: none !important;
#   color: black;
# }
#
# .ppy-pn-danger-modal{
#   border: 2px solid red;
#   border-radius: 10px;
#   box-shadow: 0px 0px 10px rgba(255, 0, 0, 0.5);
# }
#
# .ppy-pn-config-form{
#   padding: 10px;
#   margin-top: 10px;
#   margin-bottom: 10px;
#   background-color: var(--ppy-background-color2);
#   border-radius: 5px;
#   box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);
# }
#
#
# .ppy-pn-align-right {
#   display: flex;
#   justify-content: flex-end;
# }
# </style><script>function toggleMetadata(stepIndex, randomId) {
#   var metadata = document.getElementById("ppy-images-metadata-" + randomId + "-" + stepIndex);
#   var arrow = document.getElementById("ppy-images-arrow-" + randomId + "-" + stepIndex);
#   if (metadata.style.display === "none") {
#       metadata.style.display = "block";
#       arrow.innerHTML = "▼";
#       arrow.classList.remove("ppy-font-color");
#       arrow.classList.add("ppy-font-color-brown");
#   } else {
#       metadata.style.display = "none";
#       arrow.innerHTML = "►";
#       arrow.classList.remove("ppy-font-color-brown");
#       arrow.classList.add("ppy-font-color");
#   }
# }
# function toggleImage(imageId, randomId) {
#   var img = document.getElementById(imageId);
#   var arrow = document.getElementById("ppy-images-arrow-" + randomId + "-" + imageId);
#   if (img.style.display === "none") {
#       img.style.display = "block";
#       arrow.innerHTML = "▼";
#       arrow.classList.remove("ppy-font-color");
#       arrow.classList.add("ppy-font-color-brown");
#   } else {
#       img.style.display = "none";
#       arrow.innerHTML = "►";
#       arrow.classList.remove("ppy-font-color-brown");
#       arrow.classList.add("ppy-font-color");
#   }
# }
# function showMore(stepIndex) {
#   var moreImages = document.getElementById("ppy-more-images-" + stepIndex);
#   var showMoreButton = document.getElementById("ppy-show-more-button-" + stepIndex);
#   var hideButton = document.getElementById("ppy-hide-button-" + stepIndex);
#   moreImages.style.display = "flex";
#   showMoreButton.style.display = "none";
#   hideButton.style.display = "inline-block";
# }
# function hide(stepIndex) {
#   var moreImages = document.getElementById("ppy-more-images-" + stepIndex);
#   var showMoreButton = document.getElementById("ppy-show-more-button-" + stepIndex);
#   var hideButton = document.getElementById("ppy-hide-button-" + stepIndex);
#   moreImages.style.display = "none";
#   showMoreButton.style.display = "inline-block";
#   hideButton.style.display = "none";
# }
#
#
# function showParameters(id, randomId) {
#   var currentTarget = document.getElementById('ppy-pipeline-' + randomId + '-' + id);
#   var square = document.getElementsByClassName('ppy-pipeline-' + randomId);
#   var allParams = document.getElementsByClassName('ppy-pipeline-parameters-' + randomId);
#   var selectedParams = document.getElementById('ppy-pipeline-parameters-' + randomId + '-' + id);
#   var idWasVisible = false;
#   if (selectedParams) {
#       var idWasVisible = selectedParams.style.display === 'block';
#   }
#   for (var i = 0; i < square.length; i++) {
#       square[i].classList.remove('ppy-font-color-brown');
#       square[i].classList.add('ppy-font-color');
#   }
#   for (var i = 0; i < allParams.length; i++) {
#       allParams[i].style.display = 'none';
#   }
#   // Show the selected parameter section
#   if (selectedParams) {
#       if (idWasVisible) {
#           sele

# %%
# See the pipeline steps in json format
# pipeline.steps

# %%
# Run the pipeline
pipeline.run()
# Out:
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:26 | Processing images using 16 cores
# INFO:paidiverpy:Processing images using 16 cores
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:26 | Running step 0: raw - OpenLayer
# INFO:paidiverpy:Running step 0: raw - OpenLayer
# [########################################] | 100% Completed | 103.79 ms
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:27 | Step 0 completed
# INFO:paidiverpy:Step 0 completed
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:27 | Running step 1: datetime - SamplingLayer
# INFO:paidiverpy:Running step 1: datetime - SamplingLayer
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:27 | Number of images before the sampling step: 20. Total number of images after: 14
# INFO:paidiverpy:Number of images before the sampling step: 20. Total number of images after: 14
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:27 | Step 1 completed
# INFO:paidiverpy:Step 1 completed
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:27 | Running step 2: overlapping - SamplingLayer
# INFO:paidiverpy:Running step 2: overlapping - SamplingLayer
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:27 | Number of images before the sampling step: 14. Total number of images after: 9
# INFO:paidiverpy:Number of images before the sampling step: 14. Total number of images after: 9
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Step 2 completed
# INFO:paidiverpy:Step 2 completed
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Running step 3: colour_alteration - ColourLayer
# INFO:paidiverpy:Running step 3: colour_alteration - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Step 3 completed
# INFO:paidiverpy:Step 3 completed
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Running step 4: gaussian_blur - ColourLayer
# INFO:paidiverpy:Running step 4: gaussian_blur - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Step 4 completed
# INFO:paidiverpy:Step 4 completed
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Running step 5: sharpen - ColourLayer
# INFO:paidiverpy:Running step 5: sharpen - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Step 5 completed
# INFO:paidiverpy:Step 5 completed
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:28 | Running step 6: contrast - ColourLayer
# INFO:paidiverpy:Running step 6: contrast - ColourLayer
# ☁ paidiverpy ☁  |       INFO | 2025-09-11 16:48:29 | Step 6 completed
# INFO:paidiverpy:Step 6 completed
# [########################################] | 100% Completed | 1.06 sms
