# %%
import numpy as np
import sys
import os
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'src'))

import eleganplot as ep

# %%
import eleganplot as eplt
import numpy as np

# Простое использование готового метода
fig, ax = eplt.subplots()
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

# Новый gradient_plot метод
ax.gradient_plot(x, y, alpha_coef=0.2)


eplt.show()

# %%
# Новый gradient_plot метод

from eleganplot.utils import get_decay_functions

decay_funcs = get_decay_functions()
exponential_decay = decay_funcs['exponential']

fig, ax = eplt.subplots()
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
ax.glow_line(x, y, glow_width=10, decay_function=exponential_decay)


eplt.show()

# %%
import eleganplot as eplt
import numpy as np

fig, ax = eplt.subplots()
x = np.linspace(0, 4*np.pi, 200)
y = np.sin(x) * np.exp(-x/8)

# 1. Сначала gradient_plot для заливки
ax.gradient_plot(x, y,  alpha_coef=0.3, linewidth=1)

# 2. Затем glow_line для свечения
ax.glow_line(x, y, glow_width=3.0, glow_alpha=0.8)
# Out:
# (<matplotlib.lines.Line2D at 0x105b16d60>,
#  [<matplotlib.lines.Line2D at 0x105b18070>,
#   <matplotlib.lines.Line2D at 0x105b18310>,
#   <matplotlib.lines.Line2D at 0x105b185b0>,
#   <matplotlib.lines.Line2D at 0x105b18850>,
#   <matplotlib.lines.Line2D at 0x105b18af0>,
#   <matplotlib.lines.Line2D at 0x105b18d90>,
#   <matplotlib.lines.Line2D at 0x1058ba070>,
#   <matplotlib.lines.Line2D at 0x1055f3640>,
#   <matplotlib.lines.Line2D at 0x1055e3100>,
#   <matplotlib.lines.Line2D at 0x1058ba220>])
